# %%
import pandas as pd

# %%
sr = pd.Series(["as", "sd", "df"])

# %%
sr
# Out:
# 0    as
# 1    sd
# 2    df
# dtype: object

# %%
num = pd.Series([1,2,3,4])

# %%
num
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
df = pd.DataFrame({"name" : sr, "number": num})

# %%
df
# Out:
#   name  number
# 0   as       1
# 1   sd       2
# 2   df       3
# 3  NaN       4

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv("export_df.csv", index = False)

# %%
exprt = pd.read_csv("export_df.csv")

# %%
exprt
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
exprt.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %% [markdown]
# ## DEscribe Data

# %%
exprt.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
exprt.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   number  4 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 196.0+ bytes

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
clear

# %% [markdown]
# ## videving and describing data

# %%
car_sales.tail(2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.iloc[4]
# Out:
# Make                Nissan
# Colour               White
# Odometer (KM)       213095
# Doors                    4
# Price            $3,500.00
# Name: 4, dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales[car_sales["Odometer (KM)"] > 50000 ]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 5  Toyota  Green          99213      4  $4,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\rk312\AppData\Local\Temp\ipykernel_31332\3997706221.py:1: SyntaxWarning: invalid escape sequence '\$'
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')

# %%
car_sales["Price"]
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
pd.crosstab(car_sales['Doors'], car_sales['Make'])
# Out:
# Make   BMW  Honda  Nissan  Toyota
# Doors
# 3        0      0       0       1
# 4        0      3       2       3
# 5        1      0       0       0

# %%
car_sales['Price'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## manuplating Data

# %%
car_sales['Make'].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)
# Out:
# C:\Users\rk312\AppData\Local\Temp\ipykernel_31332\3620729653.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_droped = car_sales_missing.dropna()
car_droped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
seat_column = pd.Series([5,7,5,7])

# %%
car_sales["seats"] = seat_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats
# 0  Toyota  White         150043      4   400000    5.0
# 1   Honda    Red          87899      4   500000    7.0
# 2  Toyota   Blue          32549      3   700000    5.0
# 3     BMW  Black          11179      5  2200000    7.0
# 4  Nissan  White         213095      4   350000    NaN
# 5  Toyota  Green          99213      4   450000    NaN
# 6   Honda   Blue          45698      4   750000    NaN
# 7   Honda   Blue          54738      4   700000    NaN
# 8  Toyota  White          60000      4   625000    NaN
# 9  Nissan  White          31600      4   970000    NaN

# %%
car_sales["seats"].fillna(5, inplace=True)
# Out:
# C:\Users\rk312\AppData\Local\Temp\ipykernel_31332\651972956.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales["seats"].fillna(5, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats
# 0  Toyota  White         150043      4   400000    5.0
# 1   Honda    Red          87899      4   500000    7.0
# 2  Toyota   Blue          32549      3   700000    5.0
# 3     BMW  Black          11179      5  2200000    7.0
# 4  Nissan  White         213095      4   350000    5.0
# 5  Toyota  Green          99213      4   450000    5.0
# 6   Honda   Blue          45698      4   750000    5.0
# 7   Honda   Blue          54738      4   700000    5.0
# 8  Toyota  White          60000      4   625000    5.0
# 9  Nissan  White          31600      4   970000    5.0

# %%
fuel_economy = [5, 6, 7, 8, 9,5, 6, 7, 8, 9]

# %%
car_sales["Avg"] = fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  Avg
# 0  Toyota  White         150043      4   400000    5.0    5
# 1   Honda    Red          87899      4   500000    7.0    6
# 2  Toyota   Blue          32549      3   700000    5.0    7
# 3     BMW  Black          11179      5  2200000    7.0    8
# 4  Nissan  White         213095      4   350000    5.0    9
# 5  Toyota  Green          99213      4   450000    5.0    5
# 6   Honda   Blue          45698      4   750000    5.0    6
# 7   Honda   Blue          54738      4   700000    5.0    7
# 8  Toyota  White          60000      4   625000    5.0    8
# 9  Nissan  White          31600      4   970000    5.0    9

# %%
car_sales["Total fuel used new"] = car_sales["Odometer (KM)"]/100 * car_sales["Avg"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  Avg  Total fuel used
# 0  Toyota  White         150043      4   400000    5.0    5          7502.15
# 1   Honda    Red          87899      4   500000    7.0    6          5273.94
# 2  Toyota   Blue          32549      3   700000    5.0    7          2278.43
# 3     BMW  Black          11179      5  2200000    7.0    8           894.32
# 4  Nissan  White         213095      4   350000    5.0    9         19178.55
# 5  Toyota  Green          99213      4   450000    5.0    5          4960.65
# 6   Honda   Blue          45698      4   750000    5.0    6          2741.88
# 7   Honda   Blue          54738      4   700000    5.0    7          3831.66
# 8  Toyota  White          60000      4   625000    5.0    8          4800.00
# 9  Nissan  White          31600      4   970000    5.0    9          2844.00

# %%
car_sales["Nuber of wheels"] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  Avg  Total fuel used  \
# 0  Toyota  White         150043      4   400000    5.0    5          7502.15
# 1   Honda    Red          87899      4   500000    7.0    6          5273.94
# 2  Toyota   Blue          32549      3   700000    5.0    7          2278.43
# 3     BMW  Black          11179      5  2200000    7.0    8           894.32
# 4  Nissan  White         213095      4   350000    5.0    9         19178.55
# 5  Toyota  Green          99213      4   450000    5.0    5          4960.65
# 6   Honda   Blue          45698      4   750000    5.0    6          2741.88
# 7   Honda   Blue          54738      4   700000    5.0    7          3831.66
# 8  Toyota  White          60000      4   625000    5.0    8          4800.00
# 9  Nissan  White          31600      4   970000    5.0    9          2844.00
#
#    Nuber of wheels
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ...

# %%
car_sales.dtypes
# Out:
# Make                    object
# Colour                  object
# Odometer (KM)            int64
# Doors                    int64
# Price                   object
# seats                  float64
# Avg                      int64
# Total fuel used        float64
# Nuber of wheels          int64
# Total fuel used new    float64
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  Avg  Total fuel used  \
# 0  Toyota  White         150043      4   400000    5.0    5          7502.15
# 1   Honda    Red          87899      4   500000    7.0    6          5273.94
# 2  Toyota   Blue          32549      3   700000    5.0    7          2278.43
# 3     BMW  Black          11179      5  2200000    7.0    8           894.32
# 4  Nissan  White         213095      4   350000    5.0    9         19178.55
# 5  Toyota  Green          99213      4   450000    5.0    5          4960.65
# 6   Honda   Blue          45698      4   750000    5.0    6          2741.88
# 7   Honda   Blue          54738      4   700000    5.0    7          3831.66
# 8  Toyota  White          60000      4   625000    5.0    8          4800.00
# 9  Nissan  White          31600      4   970000    5.0    9          2844.00
#
#    Nuber of wheels  Total fuel used new
# 0                4              7502.15
# 1                4              5273.94
# ...

# %%
car_sales = car_sales.drop("Total fuel used new", axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  Avg  Total fuel used  \
# 0  Toyota  White         150043      4   400000    5.0    5          7502.15
# 1   Honda    Red          87899      4   500000    7.0    6          5273.94
# 2  Toyota   Blue          32549      3   700000    5.0    7          2278.43
# 3     BMW  Black          11179      5  2200000    7.0    8           894.32
# 4  Nissan  White         213095      4   350000    5.0    9         19178.55
# 5  Toyota  Green          99213      4   450000    5.0    5          4960.65
# 6   Honda   Blue          45698      4   750000    5.0    6          2741.88
# 7   Honda   Blue          54738      4   700000    5.0    7          3831.66
# 8  Toyota  White          60000      4   625000    5.0    8          4800.00
# 9  Nissan  White          31600      4   970000    5.0    9          2844.00
#
#    Nuber of wheels
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ...

# %%
car_sales.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 1   Honda    Red          87899      4   $5,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 5  Toyota  Green          99213      4   $4,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 6   Honda   Blue          45698      4   $7,500.00
# 3     BMW  Black          11179      5  $22,000.00
# 0  Toyota  White         150043      4   $4,000.00

# %%
car_sale_resuffle = car_sales.sample(frac=1)

# %%
car_sale_resuffle.reset_index(drop=True, inplace=True)

# %%
car_sale_resuffle
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0   Honda   Blue          54738      4   $7,000.00
# 1  Toyota   Blue          32549      3   $7,000.00
# 2  Nissan  White          31600      4   $9,700.00
# 3  Toyota  White          60000      4   $6,250.00
# 4   Honda    Red          87899      4   $5,000.00
# 5     BMW  Black          11179      5  $22,000.00
# 6  Nissan  White         213095      4   $3,500.00
# 7  Toyota  Green          99213      4   $4,500.00
# 8   Honda   Blue          45698      4   $7,500.00
# 9  Toyota  White         150043      4   $4,000.00

# %%
car_sale_resuffle["Odometer (KM)"] = car_sale_resuffle["Odometer (KM)"].apply(lambda x : x /1.6)

# %%
car_sale_resuffle
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0   Honda   Blue      34211.250      4   $7,000.00
# 1  Toyota   Blue      20343.125      3   $7,000.00
# 2  Nissan  White      19750.000      4   $9,700.00
# 3  Toyota  White      37500.000      4   $6,250.00
# 4   Honda    Red      54936.875      4   $5,000.00
# 5     BMW  Black       6986.875      5  $22,000.00
# 6  Nissan  White     133184.375      4   $3,500.00
# 7  Toyota  Green      62008.125      4   $4,500.00
# 8   Honda   Blue      28561.250      4   $7,500.00
# 9  Toyota  White      93776.875      4   $4,000.00
